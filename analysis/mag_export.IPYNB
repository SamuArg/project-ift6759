# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.lines import Line2D

data = [
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.190261, 'Metric3': 0.607130, 'Metadata': 'Yes_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.203522, 'Metric3': 0.579748, 'Metadata': 'Yes_Yes_No'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.192357, 'Metric3': 0.602803, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.206010, 'Metric3': 0.574611, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.207944, 'Metric3': 0.570617, 'Metadata': 'No_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.222978, 'Metric3': 0.539574, 'Metadata': 'No_Yes_No'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.210194, 'Metric3': 0.565971, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'Instance', 'Size': '200', 'Metric1': 0.229407, 'Metric3': 0.526298, 'Metadata': 'No_No_No'},
    {'Dataset': 'STEAD', 'Size': '200', 'Metric1': 0.151011, 'Metric3': 0.841128, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '200', 'Metric1': 0.152323, 'Metric3': 0.839748, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'STEAD', 'Size': '200', 'Metric1': 0.187738, 'Metric3': 0.802489, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '200', 'Metric1': 0.204787, 'Metric3': 0.784552, 'Metadata': 'No_No_No'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.222505, 'Metric3': 0.540551, 'Metadata': 'Yes_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.232558, 'Metric3': 0.519791, 'Metadata': 'Yes_Yes_No'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.222695, 'Metric3': 0.540157, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.233453, 'Metric3': 0.517944, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.240418, 'Metric3': 0.503561, 'Metadata': 'No_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.254258, 'Metric3': 0.474983, 'Metadata': 'No_Yes_No'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.243067, 'Metric3': 0.498092, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'Instance', 'Size': '100', 'Metric1': 0.256747, 'Metric3': 0.469844, 'Metadata': 'No_No_No'},
    {'Dataset': 'STEAD', 'Size': '100', 'Metric1': 0.175836, 'Metric3': 0.815011, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '100', 'Metric1': 0.179836, 'Metric3': 0.810802, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'STEAD', 'Size': '100', 'Metric1': 0.225729, 'Metric3': 0.762520, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '100', 'Metric1': 0.244768, 'Metric3': 0.742490, 'Metadata': 'No_No_No'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.252257, 'Metric3': 0.479115, 'Metadata': 'Yes_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.265610, 'Metric3': 0.451543, 'Metadata': 'Yes_Yes_No'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.255738, 'Metric3': 0.471928, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.270143, 'Metric3': 0.442183, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.277309, 'Metric3': 0.427386, 'Metadata': 'No_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.292064, 'Metric3': 0.396918, 'Metadata': 'No_Yes_No'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.276016, 'Metric3': 0.430055, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'Instance', 'Size': '50', 'Metric1': 0.293285, 'Metric3': 0.394396, 'Metadata': 'No_No_No'},
    {'Dataset': 'STEAD', 'Size': '50', 'Metric1': 0.205002, 'Metric3': 0.784326, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '50', 'Metric1': 0.215910, 'Metric3': 0.772850, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'STEAD', 'Size': '50', 'Metric1': 0.275460, 'Metric3': 0.710200, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '50', 'Metric1': 0.299965, 'Metric3': 0.684420, 'Metadata': 'No_No_No'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.293699, 'Metric3': 0.393543, 'Metadata': 'Yes_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.307232, 'Metric3': 0.365598, 'Metadata': 'Yes_Yes_No'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.292827, 'Metric3': 0.395344, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.305680, 'Metric3': 0.368803, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.318279, 'Metric3': 0.342786, 'Metadata': 'No_Yes_Yes'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.332795, 'Metric3': 0.312812, 'Metadata': 'No_Yes_No'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.320817, 'Metric3': 0.337545, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'Instance', 'Size': '25', 'Metric1': 0.334213, 'Metric3': 0.309885, 'Metadata': 'No_No_No'},
    {'Dataset': 'STEAD', 'Size': '25', 'Metric1': 0.245157, 'Metric3': 0.742081, 'Metadata': 'Yes_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '25', 'Metric1': 0.254973, 'Metric3': 0.731754, 'Metadata': 'Yes_No_No'},
    {'Dataset': 'STEAD', 'Size': '25', 'Metric1': 0.349293, 'Metric3': 0.632524, 'Metadata': 'No_No_Yes'},
    {'Dataset': 'STEAD', 'Size': '25', 'Metric1': 0.375701, 'Metric3': 0.604741, 'Metadata': 'No_No_No'}
]

df = pd.DataFrame(data)

meta_colors = {
    'No_No_No': '#440154', 'No_No_Yes': '#482878', 'No_Yes_No': '#3e4989', 'No_Yes_Yes': '#31688e',
    'Yes_No_No': '#26828e', 'Yes_No_Yes': '#1f9e89', 'Yes_Yes_No': '#6ece58', 'Yes_Yes_Yes': '#fde725'
}
meta_labels = {
    'Yes_Yes_Yes': 'Yes Yes Yes', 'Yes_No_Yes': 'Yes No Yes', 'Yes_Yes_No': 'Yes Yes No', 'Yes_No_No': 'Yes No No',
    'No_Yes_Yes': 'No Yes Yes', 'No_Yes_No': 'No Yes No', 'No_No_Yes': 'No No Yes', 'No_No_No': 'No No No'
}

datasets = ['Instance', 'STEAD']
sizes = ['200', '100', '50', '25']

fig, axes = plt.subplots(2, 4, figsize=(20, 10), sharex=True, sharey=True)
fig.suptitle('Performance by Dataset and Size', fontsize=18, fontweight='bold', y=0.98)

for i, dataset in enumerate(datasets):
    for j, size in enumerate(sizes):
        ax = axes[i, j]
        subset = df[(df['Dataset'] == dataset) & (df['Size'] == size)]
        
        for meta, color in meta_colors.items():
            pts = subset[subset['Metadata'] == meta]
            if not pts.empty:
                ax.scatter(pts['Metric1'], pts['Metric3'], 
                           c=color, marker='o', s=120, edgecolors='k', alpha=0.8)
        
        ax.set_title(f"{dataset} - Size {size}", fontsize=14, fontweight='bold')
        ax.grid(True, linestyle='--', alpha=0.6)
        
        if i == 1:
            ax.set_xlabel("MAE", fontsize=12)
        if j == 0:
            ax.set_ylabel("R²", fontsize=12)

legend_elements_meta = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, 
                               label=meta_labels[meta], markersize=12, markeredgecolor='k') 
                        for meta, color in meta_colors.items() if meta in df['Metadata'].values]

fig.legend(handles=legend_elements_meta, title="Metadata\n(Coords, Vs30, Instrument)", 
           loc='center right', bbox_to_anchor=(0.98, 0.5), fontsize=12, title_fontsize=13)

plt.tight_layout(rect=[0, 0, 0.9, 0.95])
plt.show()
